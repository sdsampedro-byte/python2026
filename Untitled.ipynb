# %%
num1 = int(input("Ingresa el numero de inicio:"))
num2 = int(input("Ingresa el numero de fin:"))

def numeros_primos(inicio, fin):
    
    for numero in range(inicio, fin + 1):
        
        if numero > 1:
            
            es_primo = True 
            
            for i in range(2, numero):
                if numero % i == 0:
                    
                   es_primo = False 
                break 
           
            if es_primo == True:
                print(numero)

numeros_primos(num1, num2)
# Out:
# Ingresa el numero de inicio: 1
# Ingresa el numero de fin: 10
# 2
# 3
# 5
# 7
# 9

# %%
inicio = int(input("Escribe el número donde empieza el rango:"))
fin = int(input("Escribe el número donde termina el rango:"))

for numero in range(inicio, fin + 1):
    
    es_primo = True
    
    if numero <= 1:
        es_primo = False
    
    for i in range(2, numero):
        if numero % i == 0:     
            es_primo = False    
            break               
    if es_primo:
        print(numero, end=
# Out:
# Escribe el número donde empieza el rango: 1
# Escribe el número donde termina el rango: 10
# 2  3  5  7
